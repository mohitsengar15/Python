# %% [markdown]
# #statistics

# %% [markdown]
# Question 1: What is a random variable in probability theory?
#
# Answer:
# A random variable is a numerical value that represents the outcome of a random experiment. It assigns a real number to each possible outcome in a sample space. For example, when rolling a die, the result (1–6) is a random variable.
#
# Question 2: What are the types of random variables?
#
# Answer:
# There are two main types of random variables:
#
# Discrete Random Variable – Takes countable values (e.g., number of students).
# Continuous Random Variable – Takes infinite values within a range (e.g., height, weight).
# Question 3: Explain the difference between discrete and continuous distributions.
#
# Answer:
#
# Discrete Distribution: Deals with countable outcomes and uses probability mass function (PMF). Example: number of heads in coin tosses.
# Continuous Distribution: Deals with continuous values and uses probability density function (PDF). Example: temperature or height.
# Question 4: What is a binomial distribution, and how is it used in probability?
#
# Answer:
# A binomial distribution models the number of successes in a fixed number of independent trials with the same probability of success.
# It is used in situations like:
#
# Number of heads in coin tosses
# Number of successful products in manufacturing
#
# Formula:
#
# P(X=k)=(
# k
# n
# 	​
#
# )p
# k
# (1−p)
# n−k
# Question 5: What is the standard normal distribution, and why is it important?
#
# Answer:
# The standard normal distribution is a normal distribution with:
#
# Mean = 0
# Standard deviation = 1
#
# It is important because it allows us to standardize any normal distribution using Z-scores, making probability calculations easier.
#
# Question 6: What is the Central Limit Theorem (CLT), and why is it critical in statistics?
#
# Answer:
# The Central Limit Theorem states that the sampling distribution of the mean approaches a normal distribution as the sample size increases, regardless of the original data distribution.
#
# It is critical because:
#
# It allows inference using normal distribution
# It helps in hypothesis testing
# It enables confidence interval estimation
# Question 7: What is the significance of confidence intervals in statistical analysis?
#
# Answer:
# A confidence interval gives a range of values within which the true population parameter is expected to lie with a certain level of confidence (e.g., 95%).
#
# Significance:
#
# Shows reliability of estimates
# Helps in decision making
# Indicates uncertainty in data
# Question 8: What is the concept of expected value in a probability distribution?
#
# Answer:
# Expected value is the average or mean value of a random variable over many trials.
#
# Formula:
#
# Discrete:
# E(X)=∑xP(x)
#
# It represents the long-term average outcome.
#
# Question 9: Python program for normal distribution
#
# Answer:

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generate random numbers
data = np.random.normal(loc=50, scale=5, size=1000)

# Calculate mean and standard deviation
mean = np.mean(data)
std_dev = np.std(data)

print("Mean:", mean)
print("Standard Deviation:", std_dev)

# Plot histogram
plt.hist(data, bins=30)
plt.title("Normal Distribution Histogram")
plt.xlabel("Values")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# Question 10: Sales Analysis using CLT
#
# Answer:
#
# Explanation:
# Using CLT, we assume the sample mean follows a normal distribution. We calculate:
#
# Mean of sales
# Standard error
# Confidence interval (95%)

# %%
import numpy as np
import scipy.stats as stats

daily_sales = [220, 245, 210, 265, 230, 250, 260, 275, 240, 255,
               235, 260, 245, 250, 225, 270, 265, 255, 250, 260]

# Mean
mean = np.mean(daily_sales)

# Standard Error
std_err = stats.sem(daily_sales)

# Confidence Interval (95%)
confidence = 0.95
interval = stats.t.interval(confidence, len(daily_sales)-1, loc=mean, scale=std_err)

print("Mean Sales:", mean)
print("95% Confidence Interval:", interval)

# %% [markdown]
# #Python Basic Question

# %% [markdown]
# 1) What is Python, and why is it popular?
#
# Answer:
# Python is a high-level programming language created by Guido van Rossum. It is popular because of its simple syntax, readability, and versatility. It is widely used in web development, data analytics, artificial intelligence, and automation. Its large library support and strong community make it easy and efficient to use.
#
# 2) What is an interpreter in Python?
#
# Answer:
# An interpreter is a program that executes Python code line by line. Instead of converting the entire code into machine language at once, it runs each instruction step by step, making debugging easier.
#
# 3) What are pre-defined keywords in Python?
#
# Answer:
# Pre-defined keywords are reserved words in Python that have special meanings and cannot be used for other purposes. Examples include if, else, while, for, True, False, and None.
#
# 4) Can keywords be used as variable names?
#
# Answer:
# No, keywords cannot be used as variable names because they are reserved for specific functions in Python.
#
# 5) What is mutability in Python?
#
# Answer:
# Mutability refers to the ability of an object to be changed after it is created. If an object can be modified, it is called mutable; otherwise, it is immutable.
#
# 6) Why are lists mutable, but tuples are immutable?
#
# Answer:
# Lists are mutable because they are designed to allow changes like adding, removing, or modifying elements. Tuples are immutable to ensure data safety and faster performance, as their values cannot be changed once created.
#
# 7) What is the difference between “==” and “is” operators in Python?
#
# Answer:
#
# == checks if two values are equal.
# is checks if two variables refer to the same object in memory.
# 8) What are logical operators in Python?
#
# Answer:
# Logical operators are used to combine conditional statements:
#
# and (both conditions must be true)
# or (at least one condition is true)
# not (reverses the condition)
# 9) What is type casting in Python?
#
# Answer:
# Type casting is the process of converting one data type into another, such as converting a string into an integer.
#
# 10) What is the difference between implicit and explicit type casting?
#
# Answer:
#
# Implicit casting: Done automatically by Python (e.g., int to float).
# Explicit casting: Done manually using functions like int(), float(), str().
# 11) What is the purpose of conditional statements in Python?
#
# Answer:
# Conditional statements are used to make decisions in a program. They execute specific blocks of code based on whether a condition is true or false.
#
# 12) How does the elif statement work?
#
# Answer:
# The elif statement stands for “else if.” It allows checking multiple conditions. If the first condition is false, Python checks the next elif condition, and so on.
#
# 13) What is the difference between for and while loops?
#
# Answer:
#
# for loop: Used when the number of iterations is known.
# while loop: Used when the number of iterations depends on a condition.
# 14) Describe a scenario where a while loop is more suitable than a for loop.
#
# Answer:
# A while loop is more suitable when the number of iterations is not known in advance.
# Example: Asking a user to enter a correct password until they get it right.

# %% [markdown]
# #Practical

# %%
1) Write a Python program to print "Hello, World!"

Answer:

print("Hello, World!")
2) Write a Python program that displays your name and age

Answer:

name = "Your Name"
age = 20

print("Name:", name)
print("Age:", age)
3) Write code to print all the pre-defined keywords in Python using the keyword library

Answer:

import keyword

print(keyword.kwlist)
4) Write a program that checks if a given word is a Python keyword

Answer:

import keyword

word = input("Enter a word: ")

if keyword.iskeyword(word):
    print("It is a Python keyword")
else:
    print("It is not a Python keyword")
5) Write a function to demonstrate the behavior of mutable and immutable arguments

Answer:

def mutable_example(lst):
    lst.append(100)
    print("Inside function (mutable):", lst)

def immutable_example(x):
    x = x + 10
    print("Inside function (immutable):", x)

# Mutable
my_list = [1, 2, 3]
mutable_example(my_list)
print("Outside function:", my_list)

# Immutable
num = 5
immutable_example(num)
print("Outside function:", num)
6) Write a program that performs basic arithmetic operations on two user-input numbers

Answer:

a = float(input("Enter first number: "))
b = float(input("Enter second number: "))

print("Addition:", a + b)
print("Subtraction:", a - b)
print("Multiplication:", a * b)
print("Division:", a / b)
7) Write a program to demonstrate the use of logical operators

Answer:

a = True
b = False

print("AND:", a and b)
print("OR:", a or b)
print("NOT:", not a)
8) Create a list and tuple, and show how changing elements works differently

Answer:

# List (mutable)
my_list = [1, 2, 3]
my_list[0] = 10
print("Modified list:", my_list)

# Tuple (immutable)
my_tuple = (1, 2, 3)
# my_tuple[0] = 10   # This will cause an error
print("Tuple remains unchanged:", my_tuple)
9) Convert user input to integer, float, and boolean

Answer:

value = input("Enter a value: ")

int_val = int(value)
float_val = float(value)
bool_val = bool(value)

print("Integer:", int_val)
print("Float:", float_val)
print("Boolean:", bool_val)
10) Demonstrate type casting with list elements

Answer:

lst = ["1", "2", "3"]

int_list = [int(i) for i in lst]
print("Converted to integers:", int_list)
11) Check if a number is positive, negative, or zero

Answer:

num = float(input("Enter a number: "))

if num > 0:
    print("Positive")
elif num < 0:
    print("Negative")
else:
    print("Zero")
12) Print numbers from 1 to 10 using a for loop

Answer:

for i in range(1, 11):
    print(i)
13) Find the sum of all even numbers between 1 and 50

Answer:

sum_even = 0

for i in range(1, 51):
    if i % 2 == 0:
        sum_even += i

print("Sum of even numbers:", sum_even)
14) Reverse a string using a while loop

Answer:

string = input("Enter a string: ")
reverse = ""
i = len(string) - 1

while i >= 0:
    reverse += string[i]
    i -= 1

print("Reversed string:", reverse)
15) Calculate factorial using a while loop

Answer:

num = int(input("Enter a number: "))

fact = 1
i = 1

while i <= num:
    fact *= i
    i += 1

print("Factorial:", fact)
